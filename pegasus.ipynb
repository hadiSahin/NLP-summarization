# %%
import pandas as pd
import re
from bs4 import BeautifulSoup
from nltk.corpus import stopwords

# %%
from transformers import PegasusForConditionalGeneration, PegasusTokenizer

model = PegasusForConditionalGeneration.from_pretrained('google/pegasus-cnn_dailymail')
tokenizer = PegasusTokenizer.from_pretrained('google/pegasus-cnn_dailymail')

text = '''The tower is 324 metres (1,063 ft) tall, about the same height as an 81-storey building, and the tallest structure in Paris. Its base is square, measuring 125 metres (410 ft) on each side. During its construction, the Eiffel Tower surpassed the Washington Monument to become the tallest man-made structure in the world, a title it held for 41 years until the Chrysler Building in New York City was finished in 1930. It was the first structure to reach a height of 300 metres. Due to the addition of a broadcasting aerial at the top of the tower in 1957, it is now taller than the Chrysler Building by 5.2 metres (17 ft). Excluding transmitters, the Eiffel Tower is the second tallest free-standing structure in France after the Millau Viaduct.                                       
'''
input_ids = tokenizer.encode(text, return_tensors='pt')
output = model.generate(input_ids)
summary = tokenizer.decode(output[0], skip_special_tokens=True)

print(summary)
# Out:
# c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\generation\utils.py:1387: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 128 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# The tower is 324 metres (1,063 ft) tall, about the same height as an 81-storey building, and the tallest structure in Paris.<n>Its base is square, measuring 125 metres (410 ft) on each side.<n>During its construction, the Eiffel Tower surpassed the Washington Monument to become the tallest man-made structure in the world.

# %%
data = pd.read_csv("data/labeled01.csv", encoding='cp1252')
data = data.dropna()
print(data.shape)
# Out:
# (955, 2)

# %%
data.head()
# Out:
#                                           resolution  \
# 0  resolution of the miami city commission accept...
# 1  resolution of the miami city commission findin...
# 2  resolution of the miami city commission author...
# 3  resolution of the miami city commission, with ...
# 4  resolution of the miami city commission, with ...
#
#                                              summary
# 0  The Miami City Commission accepted bids from r...
# 1  The Miami City Commission found that the COVID...
# 2  Miami City Commission authorizes city manager ...
# 3  Miami City Commission accepts perpetual sidewa...
# 4  Miami City Commission accepts two right-of-way...

# %%
# stop_words = set(stopwords.words('english')) 
def text_cleaner(text,num):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text #remove links
    # newString = re.sub(r'\([^)]*\)', '', newString) # remove text in the paranthesis
    newString = re.sub('_','', newString) # removing underscores
    newString = re.sub('"','', newString) # removing double quotes
    newString = re.sub('/',' ', newString) # removing double quotes
    newString = re.sub('-','', newString) # removing double quotes
    newString = re.sub(r'[^\x00-\x7F]+', '', newString) # removes non-ASCII characters
    # newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString) #remove possesive s
    # newString = re.sub("[^a-zA-Z]", " ", newString) 
    newString = re.sub('[m]{2,}', 'mm', newString)
    # if(num==0):
    #     tokens = [w for w in newString.split() if not w in stop_words]
    # else:
    #     tokens=newString.split()
    tokens=newString.split()
    long_words=[]
    for i in tokens:
        if len(i)>1:                                                 #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()

# %%
cnt=0
text = data['resolution']
results_df = pd.DataFrame(columns=['resolution', 'summary'])
for resolution in text:
    cnt+=1
    # print(cnt)
    # resolution = text_cleaner(resolution,0)
    try:  
        text = text_cleaner(resolution,0)
        input_ids = tokenizer.encode("summarize: " + text, return_tensors='pt', max_length=800, truncation=True)
        output = model.generate(input_ids, max_new_tokens=50, min_length=10)
        summary = tokenizer.decode(output[0], skip_special_tokens=True)
    except:
        summary = None
    new_row = pd.DataFrame({'resolution': text_cleaner(resolution,0), 'summary': summary}, index=[0])
    results_df = pd.concat([results_df, new_row], ignore_index=True)
    print(summary)
# Out:
# City commission meeting agenda January 13, 2022 city of Miami page printed on 2022 ca.2 11189 department of real estate and asset management resolution.<n>Bids received on February 18, 2021 pursuant to invitation for bid (ifb) no. 125
# The commission finds that the novel coronavirus 2019 pandemic has caused force majeure del ay of the performance of riverside wharf.<n>The commission authorizes an extension of the four (4) year deadline to obtain necessary building permits contained in section 29 of the charter
# resolution authorizing the city manager to negotiate and execute memorandum of agreement.<n>Florida department of transportation (fdot) to install wayfinding iosks on fdot right ofway within the city of Miami.
# Miami city commission accepts perpetual sidewalk easement.<n>Portions of sidewalks constructed on northwest 1st avenue, northwest 3rd street, northwest street, and northwest 6th street, Miami, lorida.
# Miami city commission accepted two right ofway deeds of dedication.<n>The deeds were recorded in the public records of Miami dade county, Florida.<n>The city clerk was directed to retain copies of the deeds.
# city commission meeting agenda January 13, 2022 page printed on 2022 ca.7 11039 department of police resolution.<n>accepting grant award from the florida department of transportati on (fdot) in the amount of $270,000.00 (funds)
# Miami city commission passes resolution establishing new special revenue project titled fy 2021 cops office law enforcement mental health and wellness act ('lemhwa')<n> authorize city manager to execute grant agreement to accept grant funds in the amount of $124,268.00
# This resolution establishes a new special revenue project titled bja fy 21 edwa rd byrne memorial justice assistance grant ('jag')<n>The city will accept a grant in the amount of $249,360.0 0 from the
# Miami city commission adopts resolution accepting grant award rom state of Florida.<n>New special revenue project titled 2021 2022 victims of crime act ('voca') grant consists of said grant in an amount not to exceed $571,677.00, wit
# Appropriating funds to provide resources for enforcement initiatives to reduce incidents of impaired driving and establish highway safety campaign.<n> authorizing the city manager to execute the grant agreement, in substantially the attached form, with fdot.
# resolution allocating funds in an amount not to exceed $139,413.19 for one year period to the Miami dade county association of chiefs of police.<n> account no. 00001.191501.534000.000000.
# The commission will approve the selection of the top shortlisted artists in accordance with section 62 658 of the city code to create design proposals.<n>The commission will authorize the city manager to negotiate and execute any and all necessary documents, including but not
# authorizing the city manager to accept, allocate, budget, and appropriate grant funds.<n>Grant funds for the brickell bay drive linear park and seawall flood control project.
# Miami city commission authorizing the director of finance to pay andre bernard lewis.<n>Lewis is suing the city of Miami, leslier diaz, and leonel sanchez.
# authorize the city manager to negotiate and execute the mppa with oracle credit corporation (occ)<n> authorize the city manager to take any and all actions necessary to effectuate said purchase, subject to the availability of funds and budgetary approval at the time
# allocating funds in the amount of $131,473.88 to the agencies specified in exhibit a, attached and incorporated.<n> authorizing the city manager to negotiate and execute any and all necessary documents, all in forms acceptable to the city attorney.
# Miami city commission meeting agenda January 13, 2022.<n>Commissioners will vote on allocating an amount not to exceed $1,018,719.18 in american rescue plan funds.
# City owned properties identified as folio number 01 4122 0020040 and folio number 01 4122 0020015.<n>granting perpetual, non exclusive easement with total size of approximately two thousand four hundred fifty four (2, 454) square feet
# This resolution authorize the city manager to negotiate and execute any and all necessary documents, including amen dments, extensions, and modifications, all in forms acceptable to the city attorney, subject to compliance with all applicable federal, state, and city laws
# authorizing the allocation of grant funds from the district commissioner share of the citys anti poverty initiative (api) in total amount not to exceed one hundred fifty thousand dollars ($150,000.0 0)<n> authorizing the city manager to negotiate and execute any and
# The Miami city commission will meet on January 13, 2022.<n>The commission will authorize the allocation of grant funds from the district commissioner share of the citys anti poverty initiative.<n>The commission will also authorize the city manager to negotiate and execute
# Grant funds from the district commissioner share of the city of Miamis anti poverty initiative program in total amount not to exceed one hundred fifty thousand dollars ($150,000.00)<n>Further authorizing the city manager to negotiate and execute any and all documents necessary, subject
# Four fifths (4 5ths) affirmative vote.<n> authorizing the allocation of grant funds from the district commissioner share of the citys anti poverty initiative.<n> authorizing the city manager to negotiate and execute any and all documents necessary.
# A.d.a. engineering, inc., florida profit corporation (a.d.a.) proposes to provide ivil engineering services for shorecrest road and drainage improvements.<n>Not to exceed amount of one million one hundred ninety
# resolution amending appropriations and making de appropriations and re appropriations relating to the city of Miami.<n> authorizing the city manager to make any necessary changes to adjust, ame nd, and appropriate the fiscal year 2021 2022 operating budget.<n>re
# An ordinance of the Miami city commission ame nding chapter 54 of the code of the city of Miami, Florida, as amended, titled streets and sidewalks.<n>specifically by amending article 1, titled in general, to allow advertisements on newsrack
# ordinance exempts the motorized scooter pilot program from the duration requirements pertaining to pilot programs.<n> section 33 to exempt the motorized scooter pilot program from the severability clause.<n>any propo sed ordinance listed as an item for first
# amending section 40 254 and 40 255, titled paybacks for membership credit, and benefits, respectively, to amend the service retirement benefits.<n> amending section 40 351 of the city code, titled trust fund for appointed officers and employees in executive service
# An ordinance of the Miami city commission modifying the number of attorneys in the office of the city attorney (oca) with funding, when needed or additional attorneys, as allowed, shall be by budget resolution; containing severability clause; and providing for an
# amending section 62 655(c)(4) to specify that the art in public places boards approval, approval with conditions, or denial of proposed installations, dedications, or donations of art based on the public art program guidelines and public art master plan
# An ordinance of the Miami city commission amending chapter 31 of the co de the city of Miami, Florida, as amended, titled local business tax and miscellaneous business regulations, titled local business tax and miscellaneous business regulations, titled local business tax and miscellaneous business
# Ordinance titled bicycles, skateboards, scooters, modifying and providing for additional safety measures and other regulations.<n>Adds division to provide for the permanent motorized scooter program.
# resolution of the miam city commission appoi nting certain individua ls as member of the affordable homeownership loan program task force for ter ms.<n>Commissioner alex diaz de la portilla commissioner ken russell commissioner
# resolution of the Miami city commission appointing certain individuals as members of the arts and entertainment council for terms as designated herein.<n> appointees: nominated by: commissioner alex diaz de la portilla commissioner ken russell commissioner jo ca rollo commissioner
# resolution of the Miami city commission appointing certain individual as member of the bayfront park management management tr ust for term as designated herein.<n>No action taken next: 01 13 22 result: no action taken next: 13 2022 9:00 am bc.
# Miami city commission confirms appointment of certain individual as member of the civilian investigative panel for term as designated herein.<n>No action taken next: 01 13 22 result: no action taken next: 13 2022 9:00 am city commission meeting agenda January 13, 2022
# resolution appointing ce rtain individual as member of the climate resilience committee.<n>No action taken next: 01 13 22 result: no action taken next: 13 2022 9:00 am city commission meeting agenda January 13, 2022 city of page 34 printed on 2022
# resolution of the Miami city commission appointing certain individual as member of the code compliance task force for term as designated herein.
# resolution of the Miami city commission appointing certain individuals as members of the code enforcement board.<n> appointees: nominated by: mayor francis suarez commissioner al ex diaz de la portilla com missioner ken russell commissioner joe car
# Miami city commission appointing certain individuals as members of the community relations board for terms as designated herein.<n>Mayor francis suarez commissioner alex diaz de la portilla commissioner ken russell commissioner joe carollo commissioner manolo eyes commissioner
# resolution of the Miami city commission appointing certain individuals as members of the equal pportunity advisory board.<n> appointees: nominated by: commissioner alex diaz de la portilla commissioner alex diaz de la portilla commissioner ken rus
# Miami city commission meeting agenda for January 13, 2022.<n>Commissioners nominated by: mayor francis suarez commissioner alex diaz de la portilla commissioner ken russell commissio ner joe carollo commissioner ch rist
# resolution of the Miami city commission appointing certain individual as member of the lesbian, gay, bisexual, transgender, queer (lgbtq) advisor board for term as designated here in.
# resolution of the Miami city commission appointing certain individuals as members of the health facilities authority board.<n> appointees: nominat ed by: commissioner alex diaz la portilla commissioner joe carollo commissioner manolo reyes commissioner christine
# resolution of the Miami city commission appointing certain individuals as members of the mayor council global competitiveness board.<n> appointees: nominated by: mayor francis suarez commissioner alex diaz de la portilla commissioner ken russell commissioner manolo re
# Resolution appointing certain individual as member of the miami river commission for term as designated herein.<n>Manolo reyes, commissioner, district four seconder: ken russell, alex diaz de la portilla, joe car
# resolution of the Miami city commission appointing certain individuals as members of the Miami technology council.<n> appointees: nominated by: commissioner ken russell commissioner manolo reyes comm issioner christine king commis sionatlarge history
# Miami city commission appointing certain individuals as members of the planning, zoning and appeals board.<n>Commissioner alex diaz de la portilla commissioner alex diaz de la portilla commissioner manolo reyes commissioner christine king commissioner christine
# resolution of the Miami city commission appointing certain individuals as members of the stars of calle ocho walk of fame committee for terms as designated herein.<n> appointees: nominated by: mayor francis suarez commissioner joe carol lo commissioner joe carollo commissioner
# Miami city commission appointing certain individuals as members of the urban development review board (udrb)<n> nominees: commissio ner alex diaz de la portilla commissioner alex diaz de la portilla commissioner ken russell
# Miami city commission appointing certain individual as member of the vi rginia key advisory board for term as designated herein.<n>No action taken next: 10 14 21 result: no action taken next: 10 14 2021 9:00 am 10 14 21 city
# resolution appointing certain individuals as members of the virginia key beach park trust.<n>No member of the public may address th city commission during this time.<n>Department of solid waste discussion item may be deferred.
# 12 09 21 city commission continued result: continued [unanimous] mov er: manolo reyes, commissioner, district four seconder: christine king, chair, district five ayes: christine king, joe carollo,
# amending article 1, section 1.2, tit led definitions of terms, to modify the definitions of attainable mixed income housing and workforce housing.<n> amending article 3, section 3.15, titled affordable and attainable mixed income housing special bene fit program supplemental
# An ordinance to amend appendix midtown overlay district, section 627.1.6, titled building placement and buildable area.<n> section 627.1.7, titled maximum height, build to, minimum setback and use requirements.
# An ordinance repealing chapter 62, article of the code of the city of Miami, Florida, as amended (city code), titled tree trust fund in its entirety.<n>An amendment to chapter 17 of the city code titled environmental preservation, to create
# amending section 13 16(d) titled petitions for refund of impact fe es, to provide for refunds under limited circumstances; containing severability clause, and providi ng for an effective date.
# City accepts grant from southeast overtown park west community redevelopm ent agency (cra) in an amount not to exceed $600,000.00 for provision of police enhanced services within the cra boundaries.<n> establishing new special revenue project titled southeast overtown park
# Miami city commission authorizing the director of finance to pay to and on behalf of clinton hanks, subject to the conditions imposed by chapter 440, Florida statutes, the total sum of $155,000.00, including for separate general release, in full settlement of
# transferring emergency solution grant funds in the amount of $165,316.87 from citrus health network, inc.<n> authorizing the city manager to negotiate and execute any and all necessary documents, all in forms acceptable to he city attorney.
# Miami city commission passes resolution establishing special revenue project titled 2021 2022 cops hiring program.<n>appropriating funds to the Miami police department for the hiring of fifteen (15) new law enforcement officers.<n> authorizing the city manager to execute the necessary documents
# Miami city commission co designating northwest 19th street from northwest 3rd avenue to northwest 5th avenue as bishop jacob cohen street pursuant to section 54 of the code of the city of Miami, Florida, as amended.
# Miami city commission meeting agenda for January 27, 2022.<n>Mayor francis x.<n>suarez city commission meeting agenda for January 27, 2022.
# City commission meeting agenda: January 27, 2022.<n>Commission deferred next: 01 27 22 result: deferred [unanimous] next: 27 2022 9:00 am mover: manolo reyes, commissioner, district four ayes: russell,
# An ordinance of the Miami city commission amending chapter 55 of the code of the city of Miami, Florida, as amended, titled subdivis ion regulations, as amended, titled building permits; issuance; restrictions; exceptions, to include an exception
# An ordinance of the Miami city commission modifying the number of attorneys in the office of the city attorney (oca)<n>If needed, the ordinance would be approved by separate resolution; containing se verability clause; and providing for an effective date.
# amending section 62 655(c)(4) to specify that the art in public places boards approval, approval with conditions, or denial of proposed installations, dedications, or do nations of art based on the public art program guidelines and public art master
# Discussion about the redistricting plan presentation.<n>City managers office discussion item.<n>Di.2 11313 city managers office discussion item.
# City of page 11 printed on 19 2022 di.3 11094 office of the city clerk discussion item.<n>City commission meeting agenda January 27, 2022 city of page 11 printed on 19 2022 di.3 11094 office of the city clerk discussion
# discussion regarding the annual review of the terms of elected officials as members of various trusts, authori ties, boards, committees, and agencies.<n>City commission deferred next: 01 27 22 result: deferred [unanimous] next: 27 2022
# commissioner joe carollo di.5 11380 discussion item.
# discussion regarding the status of commission ordinances and resolutions on homelessness.
# Approving an exception, with conditi ons, pursuant to article 7, section 7.1.2.6 of ordinance no. 13114.<n>All ow the re issuance of certificate of use for nonconforming uses that have lapsed for period of more
# amending article and article of mia mi 21 to prohibit gambling facilities.<n> amending article 1 titled definitions, and article 6 titled supplemental regulat ions, to prohibit ga mbling facilities.<n>finding(s) planning department recommended approval
# amending the future land use map of the miami comprehensive neighborhood plan.<n> amending the designation on the future land use map for properties at 824, 826, 834, 842, 852, 860, 68, 876
# This is an ordinance of the Miami city commission, with attachment(s), amendi ng the atlas of ordinance no. 13114.<n>Changes the zoning classification from t5 o, urban center transect open, to t6
# This will amend the designation on the future land use map for the above property from medium density mu ltifamily residential to restricted commercial and public parks and recreation.<n>planning, zoning and ppeals board motion to recommend approv al on
# rezoning of certain parcels from t5 o, urban center open, and 5r, urban center restricted, to cs, civic space, and t6 8ao, t6 8bo, and t6 12o
# An ordinance relating to the rezoning of certain parcels for the development of net 22.47 acres will be considered.<n>The parcels are located at approximately 5175 northeast avenue, 5035 northeast aven ue, and 5125 northeast court,
# An ordinance of the Miami city commission amending article 1, section 1.1 of ordinance no. 13114.<n>The purpose of this ordinance is to allow and establish definitions and regulatio ns for co living residenti al uses.<n>The
# amending ordinance no. 13114, the zoning ordinance of the city of Miami, Florida.<n> amending article 1, section 1.2, titled definition of terms; article 2, section 2.1.2, titled intent; article 2, section 2.2.4
# amending ordinance o. 13114, the zoning ordinance of the city of Miami, Florida.<n> amending article 1, titled definitions, and article 3, section 3.15, titled affordable and attainable mixed income housing special benefit program supple mental regulations
# This item presents the proper ty rights element in the format required by florida statute.<n> planning, zoning and appeal boards: on October 6, 2021, recommended approval, by vote of to 2. note for the record: pzab file id 9
# This legislation proposes changing the responsibility for making the recommendation from udrb to the historic an environmental preservation board.<n> planning, zoning and appeals board: on November 17, 2021, recomme nded approval, by vote of 2. note for
# An ordinance amending the atlas of ordinance no. 13114 was adopted.<n>It changed the classification from t3 l, sub urban transect zone limited, to t4 l, general urban transect zone limited.<n>It denied the
# This legislation clarifies regulations regarding outdoor dining.<n>outdoor dining may be ermitted by warrant in other circumstances.<n>60 day public comment period: novembe 10, 2021 january 9, 2022; pzab file id 10651 linked to
# This ordinance will amend article section 2.2.1.3 and section 2.2.2.<n>It will clarify that the miami 21 code provides higher standard of zoning for those properties located in the dade county rapid transit system.<n>development zone.
# An amendment to section 627.1.6, titled building placement and buildable area, and section 627.1.7, titled maximum height, build to, minimum setback and use requirements, is proposed.<n>Items placed in the future legislation section
# An ordinance authorizing the city manager to enter into settlement agreement with international association of fire fighters.<n>An amendment to sections 40 191, 40 203 and 40 210, titled definitions, benefits, general conditions, to amend the definition of compensation.
# City commission meeting agenda February 10, 2022 city of miam page printed on 2022 ca.2 11285 department of police resolution.<n> authorizing the city manager to approve the audit of three (3) vacant civilian positions of the city of Miami police department
# authorizing the city manager to execute the edward byrne memorial justice assis tance grant program subaward agreement.<n> authorizing the city manager to accept grant funds in the amount of $33,778.00 with no city match funds required
# City commission meeting agenda February 10, 2022 city of miam page printed in 2022 ca.4 11426 city managers office resolution.<n> authorizing the city manager to designate the chief of police or other designee to implement he transfers and appropriate use of
# Miami city commission passes resolution to eliminate neighborhood enhancement team.<n>Move constituent services closer to constituents by increasing the staff of the district and district offices.
# City commission meeting agenda February 10, 2022 city of miam page printed on 2022 ca.6 11306 departmen of resilience and public works resolution.<n>Proposal for inflatable boats, boat motors, and accessories from lifeline inflatable services inc.,
# Miami city commission, with attachment(s), accepts two (2) right ofway deeds of dedication.<n> deeds, for right ofway purposes; approving and authorizing the recordation of the deeds in the public records of Miami dade county, Florida
# City commission meeting agenda February 10, 2022 city of miam page printed on 2022 ca.8 11394 office of the city attorney resolution.<n>bids received on September 17, 2021 pursuant to invitation for bid no. 1270388.
# resolution authorizing the director of finance to pay ramon antonio castro tellez, without admission of liability, the total sum of $52,000.00 in full and complete settlement.<n>The case styled ramon antonio castro tellez vs.
# transferring emergency solution grant funds in the am ount of $165,316.87 from citrus health network, inc.<n> authorizing the city manage to negotiate and execute any and all necessary documents.
# City commission meeting agenda 10, 2022 city of miam page 11 printed on 2022 re resolutions re.1 11228 department of housing and community develop ment resolution.<n> authorizing the city manager to allocate funding on reimbursement basis to citadelle village
# City commission meeting agenda February 10, 2022 city of miam page 12 printed on 2022 re.2 11261 department of police resolution.<n> authorizing the city manager to negotiate and exeporation any and all documents, including any amendments, renewals,
# This resolution establishes a new special revenue project titled 2021 bja fy 21 byrne criminal justice innovation program.<n>This grant will provide funding for criminal justice initiatives, technical assi stance, training, equipment, and contractual support.
# City commission meeting agenda February 10, 2022.<n>Commissioners will vote on accepting a grant from the southeast overtown park west community redevelopment agency (cra)<n>Commissioners will vote on establishing a new special revenue project titled sou theas
# The Miami city commission met on January 27.<n>The agenda includes the establishment of a special revenue project titled 2021 2022 cops hiring program.<n>The commission also authorized the city manager to accept a grant for the hiring of 15 new law enforcement
# Miami city commission meeting agenda February 10, 2022.<n> authorizing the city manager to execute the grant agreements with fdeo.<n> authorizing the city manager to negotiate and execute any and all necessary documents.
# This resolution authorize the director of finance to pay to and on behalf of clinton hanks, subject to the conditions imposed by chapter 440, Florida statutes.<n>In full settlement of all claims and dates of accident alleged aga inst the
# Miami city commission co designating northwest 18th street from northwest miami court to northwest 2nd avenue.<n>Further directing the city clerk to transmit copy of this resolution to the herein designated officials.
# resolution co designating northwest 19th street from northwest 3rd avenue to northwest 5th avenue as bishop jacob cohen street pursuant to section 54 137 of the code of the cit of Miami, Florida, as amended; further directing the city clerk
# Miami city commission approves second amendment to 1996 interlocal cooperation agreement.<n>Second amendment would extend the life of the omni redevelopment district community redevelopment agency.
# Miami city commission meeting agenda February 10, 2022 printed on 2022 re.11 11365 resolution.<n>Commissioner manolo reyes history: 12 09 21 city commission deferred next: 02 10 22 result: deferred [unanimous] next: 10
# A request to film on virginia key on or about February 16, 2022 between 7:00 a.m. and 7:00 p.m.<n>A request to film on February 18, 2022 between 7:00 a.m. and 7:00 p.m.<n>A
# amend sections 40 249, 40 254, and 40 255, titled membership.<n> amend definitions of average final compensation and normal retirement age.<n> amend section 40 351 of the city code, titled trust fund for appointed officers and employees in executive
# An ordinance of the Miami city commission amending chapter 55 of the code of the city of Miami, Florida, as amended, titled subdivision regulations.
# An ordinance of the Miami city commission modifying the number of attorneys in the office of the city attorney (oca)<n>If needed, if needed, to be approved by separate resolution; containing severability clause; and providing for an effective date.
# amending section 62 655(c)(4) to specify that the art in public places boards approval, approval with conditions, or denial of proposed installations, dedications, or donations of art base on the public art program guidelines and public art master plan
# Planning and zoning planning and zoning approval for temporary uses and occupancies.<n>permi required temporary event permit novel coronavirus pilot program for vaccination and testing sites.<n>waiver time constraints for special event permits; containing severability clause
# An ordinance of the miami ci ty commission, by four fifths (4 5ths) affirmative vote, amending chapter 31 of the code of the city of Miami, Florida, as amended, titled local business tax and miscellaneous business regulations, was
# An ordinance of the Miami city commission amending chapter of the code of the city of Miami, Florida, as amended (city code)<n>It titled bicycles, skateboards, scooters, and other similar devices, modifying and providing for additional safety measures and
# Ordinance amending chapter 38 of the code of the city of Miami, lorida.<n>Will provide for the miami baywalk greenway along biscayne bay.
# City commission meeting agenda February 10, 2022 city of miam page 28 printed on 2022 di.2 11313 city managers office discu ssion item
# 01 13 22 city commission deferred next: 01 27 22 result: deferred [unanimous] next: 27 2022 9:00 am mover: alex diaz de la portilla, commissioner, district one seconde r: manolo reyes, commissioner
# discussion regarding th annual review of the terms of electe officials as members of various trusts, authorities, boards, committees, and agencies pursuant to city of Miami code section 35.
# discussion regarding the status of commission ordinances and resolutions on homelessness.<n>City commission meeting agenda February 10, 2022 city of miam page 30 printed on 2022 bc boards and committees bc.1 8938 office of the city clerk resolution
# Miami city com mission appointing certain individua ls as member of the affordable homeownership loan program task force.<n>Commissioner alex diaz de la portilla commissioner ken russell commission er manolo reyes commissioner chr
# resolution of the Miami city commission appointing certain individ uals as members of the arts and entert ainment council for terms as designated herein.
# resolution of the Miami city commission appointing certain individuals members of the audit advisory commit tee for terms as designated herein.<n> appointees: nominated by: commissioner alex diaz de la portilla commissioner ken russell commissioner joe carollo commissioner manolo
# resolution of the Miami city commission appointing certain individual as member of the bayfront park ma nagement trust for term as designated herein.<n> appointee: nominated by: gabriel paez civilian investigative panel history: 12 09 21 city commission no action taken
# resolution of the Miami city commission appoi nting certain individual as member of the climate resilience committee.<n> appointee s: nominated by: mayor francis suarez commissioner alex diaz de la portill commissioner ken russell commissioner
# resolution of the Miami city commission appointing certain individual as member of the code compliance task force for term as designated herein.
# resolution of the Miami city commission appointing certain individuals as members of the code enforcement board.<n> appointees: nominated by: commissioner alex diaz de la portilla commissioner ch ristine king commission atlarge (alternate member)
# resolution of the Miami city commission appointing certain individuals as members of the commission on the status of women and quality of life committee.<n> appointees: nominated by: mayor francis suarez commissioner alex diaz de la portilla commissioner ken
# Miami city com mission appointing certain individuals as members of the community relations board.<n>Mayor francis suarez nominated alex dia de la portilla commissioner alex diaz de la portilla commissioner ken russell commissioner joe carollo
# resolution of the Miami city commission appointing certain individuals as members of the equal opportunity advisory board.<n> appointees: nominated by: commissioner alex iaz de la portilla commissioner alex diaz de la portilla commissioner ken russell commissioner
# resolution of the Miami city commission appointing certain individuals as embers of the health facilities authority board.<n> appointees: nominated by: commissioner alex diaz de la portilla commissioner joe carollo commissi oner manolo reyes commissioner christine
# resolution of the Miami city commission appointing certain individual as member of the lesbi an, gay, bisexual, transgender, queer (lgbtq) advisory board for term as designated herein.
# resolution of the Miami city commission appointing certain individuals as member of the mayor council on global competitiveness.<n> appointees: mayor francis suarez mayor francis suarez mayor fran cis suarez mayor francis suarez commissioner alex diaz
# resolution of the Miami city commission appointing certain individuals as members of the Miami forever bond program citizens oversight board for terms as designated herein.<n> appointees: nominated by: mayor francis suarez commissioner alex diaz de la portilla commissioner ken
# resolution of the Miami city commission appointing certain individuals as members of the iami technology council.<n> nominate: commissioner ken russell commissioner manolo reyes commissioner christine king commission atlarge history.<n>no action taken next: 09
# resolution of the Miami city commission appointing certain individuals as members of the planning, zoning and appeals committee.<n> appointees: nominated by: commissioner alex diaz de la portilla commissioner alex diaz de la portilla commissioner manolo re
# resolution of the Miami city commission appointing certain individuals as members of the st ars of calle ocho walk of fame committee for terms as designated he rein.<n> appointees: nominated by: mayor francis suarez commissioner joe carollo commissioner joe
# Miami city commission appointing certain individuals as mem bers of the virginia key beach park trust.<n>Planning and zoning matters may be heard at any time.<n> pursuant to ordinance no. 13903 and section 166.041(c
# Approving a nonconformi ng use pilot program, to allow the re issuance of certificate of use for onconforming uses that have lapsed for period of more than eighteen (18) months and less than five (5) years for the properties located at 116
# An ordinance amending the zoning atlas of ordinan ce no. 13114 will be considered.<n>It will change the zoning classification from t5 o, urban center transect open, to t6 8o, urban core transect open
# An ordinance of the Miami city commission amending article 1, section 1.1 of ordinance no. 13114 is presented.<n>The purpose of the amendment is to allow and establish definitions and regulations for co living residential uses.<n>The commission will vote on
# amending article 1, section 1.2, titled definition of terms; article 2, section 2.1.2, titled intent; article 2, section 2.2.4, titled rules of construction.<n>making findings; containing severability clause; and providing for an
# amending ordinance no. 13114, the zoning ordinance of the city of Miami, Florida.<n> amending article 1, titled definitions, and article 3, section 3.15 titled affordable and attainable mixed income housing special benefit program supplemental regulations
# This item presents the property rights element in the format required by florida statute.<n>On October 6, 2021, recommended approval, by vote of to 2. note for the record: pzab file id 9460 linked to this legislative file history.
# This legislation proposes changing the responsibility for making the recommendation from udrb to the historic and environmental preservation board.<n>the hepb will be acting as recommending body only, not in its more typical quasi judicial role.<n>planning, zoning
# City commission meeting agenda Feb 10, 2022: joe carollo, ken russell, commissioner, dis trict two ayes: christine king, joe carollo, ken russell absent: alex diaz de la port
# An ordinance of the city commission amending ordinance no. 13114, the zoning ordinance of the city of Miami, Florida, as amended (miami 21 code), specifically by amending article 6, titled supplemental regulations, to provide clarification and additional stand ards
# This ordinance will amend article 2, section 2.2.1.3 and section 2.2.2.<n>It will clarify that the Miami 21 code provides higher standard of zoning for those properties located in the Miami dade county rapid transit system development zone.
# amending appendix midtown overlay district, section 627.1.6, titled building placement and buildable area.<n> section 627.1.7, titled maximum height, build to, minimum setback nd use requirements.
# This will amend article 1, section 1.2 of mi ami 21 modifying the definitions of attainable mixed income housing and workforce housing.<n>It will also add incentives including floor lot ratio bonus and new minimum unit sizes for the development of projects providing housing for
# An ordinance to change the future land use design ation from medium density restricted commercial to public parks and recreation of approximately 1.87 acres of portion of real property located at 5175 and 5035 northeast avenue and from medium density restricted commercial to restricted
# This is a request to rezone certain parcels from t5 o, urban center open, and t5 r, urban center restricted, to cs, civic space, and t6 8ao, t6 8bo,
# An ordinance relating to the rezoning of certain parcels for the development of net 22.47 acres for the sabal palm village special area plan spv sap is to be discussed.<n>The developer wishes to contribute to the reviization of the
# A request for qualifications (rfq) no. 1250387 was received for standby emergency debris and disaster recovery services.<n>The contract is for an initial term of five (5) years with an option to renew for three (3) additional two (2) year periods
# Miami city commission appointing who is member of the city commission, as the chairperson of the audit selection committee.<n> ca.3 11462 office of the city attorney resolution.
# resolution of the mi ami city commission accepting an offer to settle.<n>The lump sum payment of $60,892.57.<n> authorizing the city manager to negotiate and execute any and all documents necessary.
# Purchase of advanced nearfield detector receiver (andre), mobility enhanced spectrum analyzer (mesa), an oscor green spectrum analyzer (oscor green), an orion 2.4 non linear junction detector (orion 2.4), and telephone and line analyzer
# Appropriating funds for the operation of the urban area security initiative ('uasi') grant program fiscal year 2021.<n>Authorizing the city manager to accept the grant award and to execute the federally funded subgrant agreement.<n>
# authorizing the waiver of indemnificatio with king spalding, llp, for the provision of federal lobbying services for the city of Miami.<n> authorizing the city manager to negotiate and execute professional services agreement between the city and
# Miami city commission meeting date February 24, 2022.<n>Commission meeting page printed on 15 2022 re.4 11502 office of management and budget resolution.
# Resolution amending appropriations and making de appropriations and re appropriations relating to the general fund for the 2021 2022 fiscal year operating budget as originally authorized pursuant to resolution no. 210402 adopted September 23, 2021 (adopted oper ating budget)<n> authorizing the
# Miami city commission adopts resolution opposing senate bill 1024 (sb 1024) and house bill 741 (hb 741)<n>The bills would harm the advancement of consumer solar energy production and usage within the state of Florida.
# Miami city commission authorizes city manager to negotiate and execute urchase and sale agreement.<n>The agreement would authorize the city manager to negotiate and execute any and all necessary documents, including amendments and modifications to the ag reement.<n>The
# City commission meeting age nda 24, 2022 city of Miami page 12 printed on 15 2022 re.8 11516 resolution.<n>All allocations of Miami forever bond funds by the city commission to eligible projects are subject to the city taking any and all
# This resolution establishes a new special revenue project to provide assistance to middle class city of Miami (city) residents unable to absorb dramatic rent increases.<n>The city manager is authorized to allocate and appropriate an amount not to exceed two hundred fifty thousand,
# declaring the official intent of the city to issue tax exempt and taxable special obligation bonds.<n>reimbursing itself from the proceeds of such special obligation bonds for funds advanced by the city for certain expenses incurred with respect to certain capital improvements
# amending chapter article section 817 of the code of the city of Miami, Florida, titled administration code enforcement administrative costs, fines; liens, to amend and provide the code enforcement board guideline for mitigation of code enforcement liens by homestead and non homestead property
# Discussion regarding the bulky trash collection cost study report.<n>City commission continued result: continued [unanimous] next: 24 2022 9:00 am mover: alex diaz de la portilla, commissioner, district one seconder: manolo re
# The motion to recommend approval on October 20 2021 failed, by vote of 6.<n>planning, zoning and appeals board: the motion to recommend approval on October 20 2021 failed, by vote of 6.
# Change the transect classification from transect4 l, general urban transect zone, to t5 l, urban center transect zone limited.<n>This will change the above property from t4 general urban zone limited to t5 urban center zone
# This ordinance will amend article 2, section 2.2.1.3 and section 2.2.2.<n>It will clarify that the Miami 21 code provides higher standard of zoning for those properties located in the Miami dade county transit system development zone.<n>
# Project generally located at 700, 725, and 708 northeast 24 street, 2347 northeast avenue, 2395, 2341, 2311, 230 1, 2344, 2328, 2320, and 711 northeast 23 terrace, Miami,
# amending ordinance no. 10544, as amended, the future land use map of the miami comprehensive neighborhood plan.<n>change the future land use designation from medium density restricted commercial to restricted commerc ial.
# Change the zoning from t5 o, urban center open, to t6 8o, urban core open.<n>Properties located at approximately 8038 ortheast avenue (western portion) and 165 northeast 80 terrace.<n>Planning
# amending table 4, titled density, intensity and parking, to change the amount that the parking ratio may be reduced within transit oriented development area or within transit corridor.<n> amending table 4, titled density, intensity and parking, to change the amount hat the
# authorizing the city manager to execute maintenance memorandum of agreement (mmoa)<n> beautification improvements on state road 90 southwest 8th street from south Miami avenue to brickell plaza.<n>Department of resilience and public works resolution.
# City of Miami to execute an off system construction and maintenance agreement.<n>Improvements on state road 972 coral way from south of inte rstate 95 to east of southwest 3rd avenue.<n> reconstruction of the existing intersection to provide
# authorizing the city manager to accept perpetual sidewalk easement.<n>Portions of sidewalk constructed on the twenty five feet (25') corner radius of southeast 1st avenue and southeast 5th street.
# Approving and authorizing the recordation of the deeds in the public records of Miami dade county, Florida; further directing the city clerk to retain copies of the deeds.<n>accepting five (5) right ofway deeds of dedication as described in
# resolution authorizing the city manager to negotiate and execute joinder and consent to the agreement for water and sanitary sewer facilities.<n>establishing new special revenue titled 2021 bja 21 connect and protect: law enforcement behavioral health responses.<n>authorizing the
# City commission meeting agenda March 10, 2022 city of Miami page printed on 2022 ca.8 11399 office of grants administration resolution.<n> authorizing the city manager to submit an application for reimbursement grant funding to the florida inland navigation district.<n>
# authorizing the city manager to submit an application for reimbursement grant funding to the florida inland navigation district (find) waterways assistance program.<n>grant funds for the removal of derelict vessels.<n> authorizing the city manager to accept the grant funds for fiscal
# City commission meeting agenda March 10, 2022 city of Miami page printed on 2022 ca.10 11401 office of grants administration resolution.<n> authorizing the city manager to submit an application for reimbursement grant funding to the florida inland navigation district.<n>
# City commission meeting agenda March 10, 2022 city of Miami page 10 printed on 2022 ca.11 11402 office of grants administration resolution.<n> authorizing the city manager to submit an application for reimbursement grant funding to the florida inland navigation district waterways assistance
# City commission meeting agenda March 10, 2022 city of Miami page 11 printed on 2022 ca.12 11433 department of human services resolution.<n> authorizing the city manager to submit an application for reimbursem ent grant funding to the florida inland navigation district
# city commission meeting agenda March 10, 2022 city of Miami page 12 printed on 2022 ca.13 11586 department of parks and recreation resolution.
# This resolution provides additional authorizations for the amendment authorized by resolution no. 210262 adopted on June 24, 2021, regarding the improvements, repairs, and maintenance project at the football field and athletic track.<n>The orange bowl committee, inc. (ob
# Emergency rental and utility assistance program round reallocation funds in an amount of $409,925.36 from the united states department of the treasury.<n> authorizing the city manager to negotiate and execute any and all necess ary documents, all in forms
# City commission meeting agenda March 10, 2022 city of Miami page 14 printed on 2022 ph.3 11486 reso lution.
# Miami city commission meeting agenda March 10, 2022.<n>Commissioner manolo reyes end of public hearings city commission meeting agenda March 10, 2022 city of Miami page 15 printed on 2022 re resolutions re.1 11558 department of human resources resolution
# ratifying the collective bargaining agree ment between the city of Miami and the Miami sanitation employees american federation of state, county, and municipal employees local 871 for the period of October 1, 2020 through September 30, 2023.
# Miami city commission meeting agenda March 10, 2022 city of Miami page 16 printed on 2022 re.3 11375 department of finance resolution.<n> ratify the collective bargaining agreement between the city of Miami and the employee organization known as the fraternal order of
# authorizing the accessing of the bernalillo county.<n> authorizing the city manager to execute public transportation grant agreement.<n>accepting the state of Florida contribution, in the amount of $1,180,000.00, for capital funding for additional transit vehicles
# authorizing the city manager to submit an application for reimbursement grant funding to the florida inland navigation district.<n>Grant funds will be used for the design and permitting of shoreline stabilization, baywalk, and kayak launch at margaret pace park phase 1
# authorizing the city manager to submit an application for reimbursement grant funding to the florida inland navigation district.<n>grant funds for the construction of seawall, riverwalk, water taxi dockage, and kayak launch at jose marti park phase 2
# Miami city commission approves conceptual design park master plan.<n>Resolution rescinds any and all prior conflicting resolutions.
# adopted the amended applicable sections of the Miami dade county public art master plan as the city of Miamis public art master plan and public art program guidelines.
# Miami city commission directing the city attorney to prepare proposed amendment to charter.<n>Will authorize the city commission, by four fifths (4 5ths) affirmati ve vote, to waive competitive bidding.<n>Will amend certain terms of
# Miami city commission transfers funds from the district share of the city's anti poverty initiative (api) program.<n>Transfers $398,736.16 for the district meals program, to the district arts and entertainment and discretionary accounts for expenditures
# Miami city commission co designating southwest 2nd street from southwest 27th avenue to southwest 30th avenue as eddy caldern street.<n>Further directing the city clerk to transmit copy of this resolution to the herein designated officials.
# amending section 40 249, 40 254, and 40 255, titled memb ership; members absent from service, paybacks for membership credit, and benefits.<n> amending section 40 351 of the city code, titled trust fund for appointed
# ordinance amends chapter 62 article xiii division section 62 526 of the code of the city of Miami, Florida.<n> permit required temporary event permit novel coronavirus (covid 19) pilot program for vaccination and testing sites.
# An ordinance amending chapter article section 817 of the code of the city of Miami, Florida, as amended.<n>Code enforcement board guideline for mitigation of code enforcement liens by homestead and non homestead property owners.
# Miami city commission meeting agenda March 10, 2022.<n>Commissioner manolo reyes end of first reading ordinances city commission meeting agenda.<n>No member of the public may address the city commission during this time.
# Discussion regarding the annual report for boards committees.<n>Di.2 11463 code compliance task force discussion item.
# ...
# An annual use fee equal to two hundred ($200.00) dollars, plus taxe (if applicable)<n>For the continued use of the city owned proper ty located at 1710 northwest 22 place, folio no. 01 3134 0280200
# Approving and confirming the city manager recommendation and finding, attached and incorporated as exhibit a, that competitive negotiation methods and procedures are not practicable or advantageous to the city of Miami.<n> authorizing the city manager to negotiate and execute revocable license agreement (
# A resolution authorizing the city manager to negotiate and execute a license agreement for the use of city owned bayfront property and ancillary areas located at 2600 south bayshore drive, Miami, Florida, 33133 for the operation of public recreation center.<n>The
# Miami city commission meeting agenda November 17, 2022.<n>Four fifths (4 5ths) affirmative vote.<n>Authorizing the city manager to negotiate and execute any and all documents necessary, all in forms acceptable to the city attorney.
# A resolution authorizing the city manager to negotiate and grant agreement with camacol, inc.<n>A resolution waiving the requirements for said procedures; allocating and appropriating american rescue plan act of 2021 (arpa) coronavirus state and local
# resolution of the Miami city commission mitigating the code enforcement fine for case number ce 2021003957.<n> amount approved as full and final settlement and the city manager or designee to execute any and all documents acceptable to the city attorney.
# Approving loan in an amount not to exceed one million eight hundred thousand dollars ($1,800,000.00) in american rescue plan act of 2021 (arpa)<n>New affordable housing development will contain no fewer than sixty (60) city of Miami assisted residential
# amending appropriations relating to operational and budgetary requirements for the fiscal year ending September 30, 2022.<n> districts impacted: variou city commission meeting agenda November 17, 2022 city of Miami page 22 printed on 11 2022 re.4 12663 department of fire rescue
# Miami city commission authorizes city manager to accept grant funding in the amount of $1,332,150.00 from the department of homeland security.<n>Grant funds will be used to provide administrative and program management, training, support, equipment cache procurement, maintenance
# waiving competitive sealed bidding requirements as not being advantageous or practicable for the city of Miami.<n> authorizing the city manager to negotiate and execute any and all do cuments.<n>An approximate total amount of five hundred forty one thousand five hundred
# City commission meeting agenda November 17, 2022 re.7 12749 department of resilience and public works resolution.<n>Accepted bids from global trading, inc., florida profit corporation (global trading), the primary vendor, and design lab, inc.,
# Bird rides inc., foreign profit corporation authorized to conduct business in florida (bird), and helbiz corporation authorized to conduct business in florida (helbiz)<n> authorizing the city manager to execute the negotiated professional services agreement (psa) with
# Miami city commission to authorize city manager to execute amendment to law enforcement mutual aid agreement.<n> amendment provides for special provisions for concurrent jurisdiction and the creation of joint enforcement zones.
# Miami city commission seeks permanent signage restricting traffic on certain streets in the silver bluff neighborhood.<n>No left turn signs at all int ersection during those time periods.<n>No entry signs on the west property line both north side and
# Miami city commission waiving the two (2) temporary event limitation per year for private property.<n>Art basel week beginning December 2, 2022 and ending December 4, 2022.
# This resolution declares the official intent of the city of Miami (city) to issue both taxable and tax exempt general obligation bonds.<n>The capital projects debt millage not exceed the rate of 0.5935 mills in accordance with the November 7, 2017 bond
# The city commission will accept grant funds for the bay of pigs memorial park improvements project.<n>The commission will authorize the city manager to negotiate and execute any and all agreements, renewals, extensions, modifications, amendments, or additional documents nec
# An ordinance amending chapter 62 of the code of the city of Miami, Florida, as amended (city code), titled planning and zoning; more particularly by amending article vi, titled zoning and planning fees, section 62 22, titled schedule of fees; section
# amending section 1070 to amend the legalization process; containing severability clause; and providing for an immediate effective date.<n>City commission passed on first reading next: 11 17 22 result: passed on first reading [unanimous] next: 11
# amend section 895, titled continuances deferrals by city boards, to provide for reasonable limitations on continuances and deferrals of items by city boards.<n> amend section 895, titled continuances deferrals by city boards, to provide
# An ordinance amending chapter article section 817 of the code of the city of Miami, Florida, as amended, titled administration code enforcement administrative costs, fines, liens, to amend and provide for the allowance of 501(c)(3) and eleem osyn
# An ordinance of the Miami city commission amending chapter of the code of the city of miam i, Florida, as amended (city code)
# An ordinance naming the parcel of land consisting of approximately 35,500 square feet located at 1814 brickell avenue, Miami, Florida as tibor hollo park.
# An ordinance to allow for utdoor advertising signs at bayfront park, maurice ferre park, virginia key beach park, and department of off street parking facilities; containing severability clause; and providing for an effective date.
# An ordinance of the Miami city commission amending chapter 38 article ii of the code of the city of Miami, Florida, as amended (city cod e), ti tled parks and recreation use regulations.<n>The fine for allowing dogs to off
# An ordinance of the Miami city commission amend ing cha pter 62 article iv section 62 16 of the code of the city of Miami, Florida, as amended.<n>The ordinance is titled planning and zoning planning, zoning and appeals board appointments
# An ordinance of the city commission, with attachment(s), establishes the anti povert initiative.<n>It also provides the criteria funding and eligibility of entities under which anti poverty funds may be allocated and utilized.
# Miami city commission appointing certain individua ls as member of the affordable homeownership loan program task force for ter ms.<n>Commissioner alex diaz de la portilla commissioner ken russell commissioner joe carollo commissio
# resolution of the Miami city commi ssion ap pointing certain individuals as members of the arts and entertainment council.<n> appointees: mayor francis suarez mayor francis suarez mayor ancis suarez mayor francis suarez commissioner
# appointees: nominated by: commissioner alex diaz de la portilla commissioner ken russell commissioner joe carollo commissioner manolo reyes commissioner christin king history: 11 21 19 city commission no action taken next: 2020 9:00 am 01 09
# resolution of the Miami city commission ppointing certain individual as member of the bayfront park management trust.<n> appointee s: nominated by: commissioner ken russell commissioner joe carollo commissioner manolo reyes commissioner christin king history
# Miami city commission confirms appointment of certain individual as member of the civilian investigative panel for term as designated herein.
# resolution of the Miami city commission appointing certain individuals as members of the climate resilience committee.<n> appointees: nominated by: mayor francis suarez commissi oner alex dia de la portilla commissioner joe carollo commissioner manolo reyes
# Miami ci ty commission appoints member of code compliance task force.<n>Commissioners roll over to the next like meeting next: 02 13 20 result: rolled over to the next like meeting [3 to 2] next: 13 2020 9:00
# resolution of the Miami city commission appointing certain individuals.<n> appointees: nominated by commissioner alex diaz de la portilla commissioner ken russell commissioner manolo reyes commissioner christine king commission atlarge commiss ionatlarge
# resolution of the Miami city commission appointing certain individuals as members of the commission on the status of women and quality of life committee.<n> appointees: nominated by: mayor francis suarez commissioner alex diaz de la portilla commissioner ken
# resolution of the Miami city commission appointing certain individuals as members of the community relations board.<n> appointees: nominated by: mayor francis suarez commissioner alex diaz la portilla commissioner joe carollo commissioner manolo reyes commissioner christine
# resolution of the Miami city commission appointing certain individuals as members of the equal opportunity advisory board for terms as designated herein.<n> appointees: alex diaz de la portilla commissioner alex diaz de la portilla commissioner ken russell commissioner
# resolution of the Miami city commission appointing certain individuals as members of the health facilities authority board.<n> appointees: nominated by: commissioner alex diaz de la portilla commissioner joe carollo commissioner manolo reyes commissioner christine king history
# resolution of the Miami city commission appointing certain individuals as members of the historic and environmental preservation board.<n> commissioner alex diaz de la portilla (citizen category 7) commissioner alex diaz de la portilla (architect architectural historian category
# Miami city commiss ion appointing certai individuals as members of the housing and commerc ial loan committee.<n> appointees categories: nominated by: mayor francis uarez commission er alex diaz de la portilla
# resolution of the Miami city commission appointing certain individuals as members of the mayor council on global competitiveness.<n> appointees: mayor francis suarez mayor francis suarez mayor francis suarez commissioner alex diaz de la portilla commissioner ken
# resolution of the Miami city commission appointing certain individuals as members of the Miami forever bond program citizens oversight board.<n> appointees: nominated by: mayor francis suarez commissioner alex diaz de la portilla commissioner ken russell commissioner joe
# resolution of the mia mi city commission ap pointing certain individuals as members of the Miami technology council.<n> appointees: mayor francis suarez mayor francis suarez commissioner alex iaz de la portilla commissioner ken russell
# appointees: nominated by: commissioner manolo reyes commissioner christine king commissioner christine king city commission meeting agenda November 17, 2022 city of Miami page 79 printed on 11 2022 bc.22 3693 office of the city clerk resolu tion.
# appointees: joe carollo commissioner joe carollo commission atlarge commission atlarge commission atlarge history: 03 08 18 city commission no action taken next: 04 12 18 result: no action taken next: 12 2018 9:00 am 04 12 18 city
# resolution of the Miami city commission appointing certain individuals as members of the urban development review board (udrb)<n> appointees: nominated by: commissioner alex diaz de la portilla commissioner alex diaz de la portilla commissioner ken rus
# Miami city commission appointing certain individual as member of the vi rginia key advisory board for term as esignated herein.<n> appoint ee: nominated by: commissioner ken russell history: 09 13 21 city commission no action taken next
# Planning and zoning item(s) planning and zoning matters may be heard at any time.<n> pursuant to ordinance no. 13903 and section 166.041(c), Florida statutes, for ordinances changing the list of uses and ordinances requesting zoning
# Planning department recommends approval planning, zoning and appeals board: recommended denial on March 3, 2021, by vote of 2.<n>Commissioner ken russell applicant(s)<n>arthur noriega v, city manager on behalf of city of Miami purpose
# This legislation clarifies regulations regarding outdoor dining.<n>This will allow outdoor dining by right in particular areas of the city.<n> outdoor dining may be permitted by warrant in other circumstances.
# amending ordinance no. 13114 to permit medical marijuana dispensaries.<n> creating new definition for medical cannabis, medical marijuana di spensaries, and pharmacies.<n>further amending article 7, titled procedures to add reservati ons system and
# Motion to grant the appeal on July 6, 2022, failed, by vote of 5. note for the record: pzab file id 8675 linked to this legislative file districts impacted: district history: 22 22 city commission deferred next: 10 13 22 result
# Appellant seeks to appeal the pl anning, zoning and appeals board de cision.<n> zoning department: recommend denial of the appeal and upholding the decision of the zoning administrator to deny the certificate of use.<n> motion to grant the
# appellant seeks to appeal the planning, zoning and appeals board decision.<n>Motion to grant the appeal on July 6, 2022 faile d, by vote of 45.<n>City commission deferred next: 10 27 22 result: deferred [unanimous
# Appellant seeks to appeal the decision of the planning, zoning and appeals board which voted to grant the certificate of use.<n> zoning department: recommends that the appeal be granted, overturning the decision of the planning, zoning and appeals board.
# Appellant seeks to appeal the planning, zoning and appeals board decision.<n> zoning department recommends that the appeal be granted, overturning the decision of the planning, zoning and appeals board which voted to grant the certificate of use.
# This will amend the designation on the future land use map for the above property from medium density multifamily residential to medium density restricted commercial.<n> planning department: recommended approval (eplan pz20 6053) planning, zoning and appeals oard
# An ordinance to change the zoning classification from t3 o, sub urban transect zone open, to t4 l.<n>This will change the above property from t3 sub urban transect zone open to t4 general urban transect
# amending app endix section 5, titled specific to zones, to modify residential density calculation requirements for t4 revitalization zones.<n> amending app endix section 5, titled specific to zones, to modify residential density calculation requirements for t4
# This legislation seeks to provide specific parking reliefs related to certa in uses within the t5 and t5 zones abutting rescue mission that solely serve children.<n> planning, zoning and appeals board: scheduled on November 16, 2022.
# This will amend the designation on the future land use map for the above property from light industrial to restricted commercial medium finding(s): planning department: recommended approval.<n>planning, zoning and appeals board: scheduled on no vember 16, 2022.
# Planning, zoning and appeals board: scheduled on November 16, 2022.<n>This will change the zoning designation for the above proper ties from d1 work place district zone to t612o general urban transect zone open finding(s): planning department
# amending the future land use and the coastal management elements to address section 163.3178, florida statutes, known as the peril of flood requirements.<n> amending the relevant appendices of the mcnp with relevant data and analyses.<n>the legislation further
# amending table 4, titled density, intensity and parking, to change the method by which the parking ratio may be reduced within opportunity zones.<n> recommending approval planning, zoning and appeals boards: scheduled on November 6, 2022.
# amending article secti on 7.1.1.4, titled procedures and nonconformities planning, zoning and appeals board.<n> amending article secti on 7.1.1.4, titled procedures and nonconformities planning, zoning and appeals board, to simplify the

# %%
print(data.shape)
# Out:
# (955, 2)

# %%
print(results_df.shape)
# Out:
# (955, 2)

# %%
results_df2 = results_df.dropna()
print(results_df2.shape)
# Out:
# (955, 2)

# %%
results_df2.to_csv('data/summaries_pgs.csv', index=False)
